# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiwon880/DataAnalysis_23/blob/main/jaiwon880/ch06_03_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84_%EC%8B%AC%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터프레임의 합성

# %% [markdown]
# * `numpy` 배열을 합치는 것
#   * `concatenate`, `vstack`(열 사이즈), `hstack`(행)
#   * `dstack`(m x n), `stack`(m x n) ... 모양이 맞는 것들을 연결

# %% [markdown]
# > 1:1로 연결
#
# |이름|전화번호|
# |-|-|
# |김제육|010-xxxx-xxxx|
# |이김치|010-xxxx-xxxx|
#
# |이름|주소|
# |-|-|
# |김제육|서울시 제육구|
# |이김치|경기도 김치시|
#
# ↓
#
# |이름|전화번호|주소|
# |-|-|-|
# |김제육|010-xxxx-xxxx|서울시 제육구|
# |이김치|010-xxxx-xxxx|경기도 김치시|
#
# `이름` : `공통 열`
# 행 라벨 -> 열, 이름. 행 인덱스
# 0~10....

# %% [markdown]
# > 1:M 로 연결 (공통 행이 없으면 사라짐)
#
# |이름|주소|
# |-|-|
# |A|서울시|
# |B|경기도|
# |C|서울시|
# |D|울산시|
#
# |주소|지원금|
# |-|-|
# |서울시|10000|
# |경기도|11100|
# |인천시|20000|
#
# ↓
#
# |이름|주소|지원금|
# |-|-|-|
# |A|서울시|10000|
# |B|경기도|11100|
# |C|서울시|10000|

# %% [markdown]
# ## `merge` (두 개 이상의 데이터프레임을 join, 연결)

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1 # 고객 목록
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2 # 구매 기록
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# merge : 결합하다 -> pandas.merge(df1, df2) # df1 (left), df2 (right)
pd.merge(df1, df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
pd.merge(left = df1, right = df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
pd.merge(left = df2, right = df1)
# Out:
#    고객번호     금액   이름
# 0  1001  10000   둘리
# 1  1001  20000   둘리
# 2  1001  30000   둘리
# 3  1005  15000   희동
# 4  1006   5000  마이콜

# %%
pd.merge(left = df1, right = df2, on="고객번호")
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
df1, df2
# Out:
# (   고객번호   이름
#  0  1001   둘리
#  1  1002  도우너
#  2  1003   또치
#  3  1004   길동
#  4  1005   희동
#  5  1006  마이콜
#  6  1007   영희,    고객번호      금액
#  0  1001   10000
#  1  1001   20000
#  2  1005   15000
#  3  1006    5000
#  4  1008  100000
#  5  1001   30000)

# %%
pd.merge(left = df1, right = df2, on="고객번호", how="inner")
# inner join: (기준되는 열) 양쪽 데이터 프레임에 모두 속하는 원소들만 남겨줌
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
pd.merge(df1, df2, how="inner") # default = inner
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
pd.merge(df1, df2, how="outer") # 다 살리고 싶으면 outjoin (고윳 값이 있다면 전부 다 가져옴)
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %%
pd.merge(df1, df2, how="left")
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
pd.merge(df1, df2, how="right") # df2 구매기록을 기준으로 붙여줌
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
df1 = pd.DataFrame({
    '품종': ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이': [1.4, 1.3, 1.5, 1.3]},
    columns=['품종', '꽃잎길이'])
df1
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
df1.품종.value_counts()
# Out:
# setosa       2
# virginica    2
# Name: 품종, dtype: int64

# %%
df2 = pd.DataFrame({
    '품종': ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비': [0.4, 0.3, 0.5, 0.3]},
    columns=['품종', '꽃잎너비'])
df2
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
df2.품종.value_counts()
# Out:
# virginica     2
# setosa        1
# versicolor    1
# Name: 품종, dtype: int64

# %%
pd.merge(df1, df2)
# 공통으로 존재하는 열을 찾음(품종)
# 품종들이 몇개씩 있는지 -> 같은 열에 동일한 원소가 여러 개
# -> 원소들끼리의 모든 경우의 수 (조합)을 만들어냄
# inner (df1, df2가 모두 존재하는 걸로만 연결)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %%
pd.merge(df1, df2, how="outer")
# Out:
#            품종  꽃잎길이  꽃잎너비
# 0      setosa   1.4   0.4
# 1      setosa   1.3   0.4
# 2   virginica   1.5   0.3
# 3   virginica   1.5   0.5
# 4   virginica   1.3   0.3
# 5   virginica   1.3   0.5
# 6  versicolor   NaN   0.3

# %% [markdown]
# ### 연결되면 안되는 열의 이름이 같을 때

# %%
# 두 df에서 이름이 같은 열은 모두 연결하는 기준 (키=on)
# 이름은 같아도 키가 되면 안되는 열 => `on` 무엇을 기준을 할지 명시
# (학생) 수업ID / 이름 (학생의 이름)
# (수업) 수업ID / 이름 (수업의 이름)
# -> on=[수업ID, 이름] ??? -> on='수업ID'
df1 = pd.DataFrame({
    '고객명': ['춘향', '춘향', '몽룡'],
    '날짜': ['2018-01-01', '2018-01-02', '2018-01-01'],
    '데이터': ['20000', '30000', '100000']})
df1
# Out:
#   고객명          날짜     데이터
# 0  춘향  2018-01-01   20000
# 1  춘향  2018-01-02   30000
# 2  몽룡  2018-01-01  100000

# %%
df2 = pd.DataFrame({
    '고객명': ['춘향', '몽룡'],
    '데이터': ['여자', '남자']})
df2
# Out:
#   고객명 데이터
# 0  춘향  여자
# 1  몽룡  남자

# %%
# pd.merge(df1, df2)
pd.merge(df1, df2, on=["고객명","데이터"])
# Out:
# Empty DataFrame
# Columns: [고객명, 날짜, 데이터]
# Index: []

# %%
pd.merge(df1, df2, on="고객명") # 겹치는 데이터에 대해서 x, y를 붙여서 나타내줌
# Out:
#   고객명          날짜   데이터_x 데이터_y
# 0  춘향  2018-01-01   20000    여자
# 1  춘향  2018-01-02   30000    여자
# 2  몽룡  2018-01-01  100000    남자

# %%
# suffix -> 접미사 , prefix -> 접두사
pd.merge(df1, df2, on="고객명", suffixes=["_A","_B"])
# Out:
#   고객명          날짜   데이터_A 데이터_B
# 0  춘향  2018-01-01   20000    여자
# 1  춘향  2018-01-02   30000    여자
# 2  몽룡  2018-01-01  100000    남자

# %% [markdown]
# ### 연결하는 기준이 되는 열들의 이름이 다를 때

# %%
df1 = pd.DataFrame({
    '이름': ['영희', '철수', '철수'],
    '성적': [1, 2, 3]})
df1
# Out:
#    이름  성적
# 0  영희   1
# 1  철수   2
# 2  철수   3

# %%
df2 = pd.DataFrame({
    '성명': ['영희', '영희', '철수'],
    '성적2': [4, 5, 6]})
df2 # df2['이름'] = df2['성명'], df2.drop...['성명']??, rename...
# Out:
#    성명  성적2
# 0  영희    4
# 1  영희    5
# 2  철수    6

# %%
pd.merge(df1, df2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-35-bf676d91be05> in <module>
# ----> 1 pd.merge(df1, df2)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     679             warnings.warn(msg, FutureWarning, stacklevel=3)
#     680
# --> 681         self._validate_specification()
#     682
#     683         cross_col = None
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1344                 common_cols = left_cols.intersection(right_cols)
#    1345                 if len(common_cols) == 0:
# -> 1346                     raise MergeError(
#    1347                         "No common columns to perform merge on. "
#    1348                         f"Merge options: left_on={self.left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
# pd.merge(df1, df2, left_on='이름', right_on='성명')
pd.merge(df1, df2, left_on='이름', right_on='성명')
# Out:
#    이름  성적  성명  성적2
# 0  영희   1  영희    4
# 1  영희   1  영희    5
# 2  철수   2  철수    6
# 3  철수   3  철수    6

# %%
df01 = pd.merge(df1, df2, left_on='이름', right_on='성명')
df01.drop("성명", inplace=True, axis=1)
df01
# Out:
#    이름  성적  성적2
# 0  영희   1    4
# 1  영희   1    5
# 2  철수   2    6
# 3  철수   3    6

# %% [markdown]
# ### 인덱스를 기준으로 합쳐주고 싶을 때

# %%
df1 = pd.DataFrame({
    '도시': ['서울', '서울', '서울', '부산', '부산'],
    '연도': [2000, 2005, 2010, 2000, 2005],
    '인구': [9853972, 9762546, 9631482, 3655437, 3512547]})
df1
# Out:
#    도시    연도       인구
# 0  서울  2000  9853972
# 1  서울  2005  9762546
# 2  서울  2010  9631482
# 3  부산  2000  3655437
# 4  부산  2005  3512547

# %%
import numpy as np
df2 = pd.DataFrame(
    np.arange(12).reshape((6, 2)),
    index=[['부산', '부산', '서울', '서울', '서울', '서울'],
           [2000, 2005, 2000, 2005, 2010, 2015]],
    columns=['데이터1', '데이터2'])
df2
# Out:
#          데이터1  데이터2
# 부산 2000     0     1
#    2005     2     3
# 서울 2000     4     5
#    2005     6     7
#    2010     8     9
#    2015    10    11

# %%
pd.merge(df1, df2, left_on=["도시", "연도"], right_index=True) # right 인덱스를 기준으로 붙여주겠다
# Out:
#    도시    연도       인구  데이터1  데이터2
# 0  서울  2000  9853972     4     5
# 1  서울  2005  9762546     6     7
# 2  서울  2010  9631482     8     9
# 3  부산  2000  3655437     0     1
# 4  부산  2005  3512547     2     3

# %%
df2.reset_index()
# Out:
#   level_0  level_1  데이터1  데이터2
# 0      부산     2000     0     1
# 1      부산     2005     2     3
# 2      서울     2000     4     5
# 3      서울     2005     6     7
# 4      서울     2010     8     9
# 5      서울     2015    10    11

# %%
pd.merge(df1, df2.reset_index(),
         left_on=["도시", "연도"],
         right_on = ["level_0", "level_1"])
# Out:
#    도시    연도       인구 level_0  level_1  데이터1  데이터2
# 0  서울  2000  9853972      서울     2000     4     5
# 1  서울  2005  9762546      서울     2005     6     7
# 2  서울  2010  9631482      서울     2010     8     9
# 3  부산  2000  3655437      부산     2000     0     1
# 4  부산  2005  3512547      부산     2005     2     3

# %% [markdown]
# ### `join`을 통한 합성

# %%
# pd.merge(left, right, ...) # on? index?... how?
# df1 -> left
df1 = pd.DataFrame({
    '품종': ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이': [1.4, 1.3, 1.5, 1.3]},
    columns=['품종', '꽃잎길이'])
df2 = pd.DataFrame({
    '품종': ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비': [0.4, 0.3, 0.5, 0.3]},
    columns=['품종', '꽃잎너비'])
df1, df2
# Out:
# (          품종  꽃잎길이
#  0     setosa   1.4
#  1     setosa   1.3
#  2  virginica   1.5
#  3  virginica   1.3,            품종  꽃잎너비
#  0      setosa   0.4
#  1   virginica   0.3
#  2   virginica   0.5
#  3  versicolor   0.3)

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-f8069890b6d0> in <module>
# ----> 1 df1.join(df2)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     119         validate=validate,
#     120     )
# --> 121     return op.get_result()
#     122
#     123
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in get_result(self)
#     715         join_index, left_indexer, right_indexer = self._get_join_info()
#     716
# --> 717         llabels, rlabels = _items_overlap_with_suffix(
#     718             self.left._info_axis, self.right._info_axis, self.suffixes
#     719         )
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2312
#    2313     if not lsuffix and not rsuffix:
# -> 2314         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2315
#    2316     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['품종'], dtype='object')

# %%
# join: 두 개의 df을 인덱스 기준으로 합쳐주는 메소드
df1.join(df2, lsuffix="l", rsuffix="r") # 인덱스가 있는 기준으로 합쳐버림 join (index 기준)
# Out:
#          품종l  꽃잎길이         품종r  꽃잎너비
# 0     setosa   1.4      setosa   0.4
# 1     setosa   1.3   virginica   0.3
# 2  virginica   1.5   virginica   0.5
# 3  virginica   1.3  versicolor   0.3

# %%
df1.set_index("품종").join(df2.set_index("품종")) # 같은 시계열 데이터 - 인덱스가 같을 때
# Out:
#            꽃잎길이  꽃잎너비
# 품종
# setosa      1.4   0.4
# setosa      1.3   0.4
# virginica   1.5   0.3
# virginica   1.5   0.5
# virginica   1.3   0.3
# virginica   1.3   0.5

# %% [markdown]
# ### `merge`
# - 두 데이터프레임 사이의 크기가 같을 필요가 없음 (기준이 되는 열, 인덱스를 바탕으로 outer, inner... 내용들을 재구성
# - `on` ... -> 어떠한 열을 기준으로 해줄까? `index`...
# - 두 개의 데이터가 공통 분모만 있다면 (키) 연결
# - 열 기준으로 연결할 필요가 없다? `join` -> 인덱스를 기준

# %% [markdown]
# ## `concat`
# * `merge` : 특정한 열을 기준(또는 인덱스)으로 해서 연결
# * `concat` : 기준 열을 사용하지 않고 데이터를 연결(붙임) - np.concatenate, vstack, hstack...

# %%
s1 = pd.Series([0, 1], index=['A', 'B'])
s2 = pd.Series([2, 3, 4], index=['A', 'B', 'C'])

# %%
s1
# Out:
# A    0
# B    1
# dtype: int64

# %%
s2
# Out:
# A    2
# B    3
# C    4
# dtype: int64

# %%
# pd.concat
pd.concat([s1, s2]) # axis가 행 방향이다 axis = 0
# Out:
# A    0
# B    1
# A    2
# B    3
# C    4
# dtype: int64

# %%
pd.concat([s1, s2], axis=1) # 열방향으로 합쳐짐, 열 이름이 같아도 연결됨.
# Out:
#      0  1
# A  0.0  2
# B  1.0  3
# C  NaN  4

# %% [markdown]
# # 피봇테이블과 그룹 분석

# %% [markdown]
# ## 피봇테이블
# * Pivot Table : 데이터 열 중에서 두 개의 열을 각각 행과 열 인덱스로 사용해서 데이터를 조회해 놓은 것
# * 엑셀 -> 피봇테이블
# * Pandas -> 피봇테이블 `pivot` (행 인덱스로 사용할 열이름, 열 인덱스로 사용할 열 이름)

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]

# %%
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
# 행 인덱스, 열 인덱스, 묶어줄 데이터 
df1.pivot("도시", "연도", "인구") # 행/열 인덱스를 만족시키는 데이터가 없으면 NaN 처리
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
# 조건을 만족시키는 데이터가 2개 이상일 경우에는 pivot table X
df1.pivot("지역", "연도", "인구")  # (서울, 인천)수도권이 겹침
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1956707dc840> in <module>
#       1 # 조건을 만족시키는 데이터가 2개 이상일 경우에는 pivot table X
# ----> 2 df1.pivot("지역", "연도", "인구")  # (서울, 인천)수도권이 겹침
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7883         from pandas.core.reshape.pivot import pivot
#    7884
# -> 7885         return pivot(self, index=index, columns=columns, values=values)
#    7886
#    7887     _shared_docs[
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    4155         from pandas.core.reshape.reshape import unstack
#    4156
# -> 4157         return unstack(self, level, fill_value)
#    4158
#    4159     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     489         if is_1d_only_ea_dtype(obj.dtype):
#     490             return _unstack_extension_series(obj, level, fill_value)
# --> 491         unstacker = _Unstacker(
#     492             obj.index, level=level, constructor=obj._constructor_expanddim
#     493         )
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     138             )
#     139
# --> 140         self._make_selectors()
#     141
#     142     @cache_readonly
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     190
#     191         if mask.sum() < len(self.index):
# --> 192             raise ValueError("Index contains duplicate entries, cannot reshape")
#     193
#     194         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df1.set_index(["도시", "연도"])
# Out:
#               인구   지역
# 도시 연도
# 서울 2015  9904312  수도권
#    2010  9631482  수도권
#    2005  9762546  수도권
# 부산 2015  3448737  경상권
#    2010  3393191  경상권
#    2005  3512547  경상권
# 인천 2015  2890451  수도권
#    2010   263203  수도권

# %%
df1.set_index(["도시", "연도"])[["인구"]]
# Out:
#               인구
# 도시 연도
# 서울 2015  9904312
#    2010  9631482
#    2005  9762546
# 부산 2015  3448737
#    2010  3393191
#    2005  3512547
# 인천 2015  2890451
#    2010   263203

# %%
df1.set_index(["도시", "연도"])[["인구"]].unstack()
# Out:
#            인구
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %% [markdown]
# ## 그룹분석
# * 조건에 맞는 데이터가 하나 이상일 경우에 -> 데이터 그룹을 이룸 (피봇 테이블 형태로 표현을 X)
# * 그룹의 특성을 보여주는 (통계치, 계산...) => 그룹 분석 (group analysis)
# * group -> `groupby`
#
# 1. 분석하고자 하는 Series, df에 `groupby` 메소드 호출 -> 그룹화
# 1. 그룹화 -> 그룹 객체 -> 그룹 연산

# %% [markdown]
# ### groupby 메소드
# * 데이터를 그룹별로 분류하는 역할.
#     * 열 또는 열의 리스트 (어떤 열을 기준으로 그룹을 넣어줄 것이냐
#     * 행 인덱스
# => GroupBy (그룹화) => 그룹 함수 or 그룹 연산 => 특정한 값. 배열...

# %%
np.random.seed(0)
df2 = pd.DataFrame({
    'key1': ['A', 'A', 'B', 'B', 'A'],
    'key2': ['one', 'two', 'one', 'two', 'one'],
    'data1': [1, 2, 3, 4, 5],
    'data2': [10, 20, 30, 40, 50]
})
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key1    5 non-null      object
#  1   key2    5 non-null      object
#  2   data1   5 non-null      int64
#  3   data2   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
# groups = df2.groupby(df2.key1)
groups = df2.groupby(df2["key1"])
groups

# %%
list(groups)
# Out:
# [('A',   key1 key2  data1  data2
#   0    A  one      1     10
#   1    A  two      2     20
#   4    A  one      5     50), ('B',   key1 key2  data1  data2
#   2    B  one      3     30
#   3    B  two      4     40)]

# %%
# groupby.groups(속성) : 그룹별 구성 현황(행 인덱스)
groups.groups
# Out:
# {'A': [0, 1, 4], 'B': [2, 3]}

# %%
groups.count()  #데이터 세는 거, NaN 빼고
# Out:
#       key2  data1  data2
# key1
# A        3      3      3
# B        2      2      2

# %%
df3 = df2.copy()
df3.iloc[1,1] = np.nan
df3
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  NaN      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
df3.groupby(df3.key1).count()
# Out:
#       key2  data1  data2
# key1
# A        2      3      3
# B        2      2      2

# %%
groups.size() # len() 그룹데이터의 행의 갯수
# Out:
# key1
# A    3
# B    2
# dtype: int64

# %%
df3.groupby(df3.key1).size()
# Out:
# key1
# A    3
# B    2
# dtype: int64

# %%
# 평균
groups.mean()
# Out:
#          data1      data2
# key1
# A     2.666667  26.666667
# B     3.500000  35.000000

# %%
# 중앙값 (median)
groups.median()
# Out:
#       data1  data2
# key1
# A       2.0   20.0
# B       3.5   35.0

# %%
# 최대값
groups.max()
# Out:
#      key2  data1  data2
# key1
# A     two      5     50
# B     two      4     40

# %%
# 최소값
groups.min()
# Out:
#      key2  data1  data2
# key1
# A     one      1     10
# B     one      3     30

# %%
# 합계
groups.sum()
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
# 일괄적으로 곱함
groups.prod() # 누적해서 더하는 건 sumprod
# Out:
#       data1  data2
# key1
# A        10  10000
# B        12   1200

# %%
# 표준편차, 분산, 중간값(50%)
groups.std()
# Out:
#          data1      data2
# key1
# A     2.081666  20.816660
# B     0.707107   7.071068

# %%
groups.var()
# Out:
#          data1       data2
# key1
# A     4.333333  433.333333
# B     0.500000   50.000000

# %%
groups.quantile(0.5)
# Out:
# <ipython-input-34-df97294cd3b1>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   groups.quantile(0.5)
#       data1  data2
# key1
# A       2.0   20.0
# B       3.5   35.0

# %%
groups.quantile(0.25), groups.quantile(0.75) # 1, 3 사분위수
# Out:
# <ipython-input-35-3b297bc2130c>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   groups.quantile(0.25), groups.quantile(0.75) # 1, 3 사분위수
# (      data1  data2
#  key1
#  A      1.50   15.0
#  B      3.25   32.5,       data1  data2
#  key1
#  A      3.50   35.0
#  B      3.75   37.5)

# %%
# 특정한 열만 뽑아주고 싶다
groups.quantile(0.75).data1
# Out:
# <ipython-input-36-2749271796c0>:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   groups.quantile(0.75).data1
# key1
# A    3.50
# B    3.75
# Name: data1, dtype: float64

# %% [markdown]
# ### 복합키

# %%
# df.groupby([key1, key2])
# df1.groupby("도시")["인구"].sum()
# df1.groupby("지역")["인구"].sum()
df1.groupby(["지역", "도시"])[["인구"]].sum()
# Out:
#               인구
# 지역  도시
# 경상권 부산  10354475
# 수도권 서울  29298340
#     인천   3153654

# %%
df2.data1.groupby([df2.key1, df2.key2]).sum()
# Out:
# key1  key2
# A     one     6
#       two     2
# B     one     3
#       two     4
# Name: data1, dtype: int64

# %%
# unstack 인덱스 중에 해당 인덱스를 열로 다시 배치
df2.data1.groupby([df2.key1, df2.key2]).sum().unstack("key2")
# Out:
# key2  one  two
# key1
# A       6    2
# B       3    4

# %%
# 2개 이상의 키를 사용해주려면 [] 담아야함
df1.groupby([df1.지역, df1.연도]).sum().unstack("연도")
# Out:
#           인구
# 연도      2005     2010      2015
# 지역
# 경상권  3512547  3393191   3448737
# 수도권  9762546  9894685  12794763

# %% [markdown]
# ### agg (aggregate)

# %%
import seaborn as sns # 예시 데이터들을 불러올 수 있음
iris = sns.load_dataset('iris') # 붓꽃
iris # 붓꽃의 데이터
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
def peak_to_peak_ratio(x):
  return x.max() / x.min()

# %%
# 각 붓꽃의 종별로 (열별로) 가장 큰 값과 가장 작은 값의 비율을 구해보기
# sepal (꽃받침) / petal(꽃잎)
# iris .groupby(iris.species).agg(lambda x: x.max() / x.min())
iris .groupby(iris.species).agg(peak_to_peak_ratio)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          1.348837     1.913043      1.900000     6.000000
# versicolor      1.428571     1.700000      1.700000     1.800000
# virginica       1.612245     1.727273      1.533333     1.785714

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris .groupby(iris.species).agg(lambda x: x.max() / x.min())
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          1.348837     1.913043      1.900000     6.000000
# versicolor      1.428571     1.700000      1.700000     1.800000
# virginica       1.612245     1.727273      1.533333     1.785714

# %% [markdown]
# * `agg` : 그룹 들의 대표값
# * `apply` : 그룹들로 나뉘어진 행에 대해서 반복적 연산

# %%
# 꽃잎의 길이가 가장 긴 상위 3개
def top3_petal_length(df): # group
  return df.sort_values(by="petal_length", ascending=False)[:3]

def top1_petal_length(df): # group
  return df.sort_values(by="petal_length", ascending=False)[:1]

iris.groupby(iris.species).apply(top3_petal_length)
iris.groupby(iris.species).apply(top1_petal_length)
# Out:
#                 sepal_length  sepal_width  petal_length  petal_width  \
# species
# setosa     24            4.8          3.4           1.9          0.2
# versicolor 83            6.0          2.7           5.1          1.6
# virginica  118           7.7          2.6           6.9          2.3
#
#                    species
# species
# setosa     24       setosa
# versicolor 83   versicolor
# virginica  118   virginica

# %% [markdown]
# # 시계열 자료 다루기
# * 인덱스가 시간 또는 날짜인 데이터 -> 순서가 시간/날짜 데이터에 따라 정해져있음
# * 시계열 데이터의 인덱스 `DatetimeIndex`
# ```
# 2022-12-09 <- 텍스트 형태로 인덱스가 제공. => `DatetimeIndex`
# ```
# * 꼭 일정 기간에 꽉차져있는 형태로 인덱스가 X (날짜 형식만 지키면 됨)
# ---
# * `pd.to_datetime`
# * `pd.date_range`

# %%
# pd.to_datetime => (시간, 날짜 형태로 표현된 데이터들의 나열된 리스트...) => DatetimeIndex
date_str = ["2023. 1. 1", "2023. 1. 4", "2023. 1. 5", "2023. 1. 6"]
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-04', '2023-01-05', '2023-01-06'], dtype='datetime64[ns]', freq=None)

# %%
s = pd.Series(np.random.rand(len(idx)), index=idx)
s
# Out:
# 2023-01-01    0.548814
# 2023-01-04    0.715189
# 2023-01-05    0.602763
# 2023-01-06    0.544883
# dtype: float64

# %%
# pd.date_range : range, arange처럼 시작일/종료일 또는 시작일/기간을 입력하면 범위 내의 시간/날짜 인덱스를 생성
# 1. 시작일과 종료일
pd.date_range("2023-4-1", "2023-4-30") #freq: 빈도 => D (day)/
pd.date_range("2023-4-1", "2023-4-30", freq="D") #freq: 빈도 => D (day)
# Out:
# DatetimeIndex(['2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06', '2023-04-07', '2023-04-08',
#                '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16',
#                '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#                '2023-04-21', '2023-04-22', '2023-04-23', '2023-04-24',
#                '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28',
#                '2023-04-29', '2023-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
# 2. 시작일과 기간
# pd.date_range('2023-4-1', periods=30)
pd.date_range('2023-4-1', periods=30, freq="D")
# Out:
# DatetimeIndex(['2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04',
#                '2023-04-05', '2023-04-06', '2023-04-07', '2023-04-08',
#                '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16',
#                '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#                '2023-04-21', '2023-04-22', '2023-04-23', '2023-04-24',
#                '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28',
#                '2023-04-29', '2023-04-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2023-4-1', periods=30, freq="M")  # 끝날로 감
# Out:
# DatetimeIndex(['2023-04-30', '2023-05-31', '2023-06-30', '2023-07-31',
#                '2023-08-31', '2023-09-30', '2023-10-31', '2023-11-30',
#                '2023-12-31', '2024-01-31', '2024-02-29', '2024-03-31',
#                '2024-04-30', '2024-05-31', '2024-06-30', '2024-07-31',
#                '2024-08-31', '2024-09-30', '2024-10-31', '2024-11-30',
#                '2024-12-31', '2025-01-31', '2025-02-28', '2025-03-31',
#                '2025-04-30', '2025-05-31', '2025-06-30', '2025-07-31',
#                '2025-08-31', '2025-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2023-4-1', periods=30, freq="MS")  # 끝날로 감
# Out:
# DatetimeIndex(['2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01',
#                '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01',
#                '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01',
#                '2024-12-01', '2025-01-01', '2025-02-01', '2025-03-01',
#                '2025-04-01', '2025-05-01', '2025-06-01', '2025-07-01',
#                '2025-08-01', '2025-09-01'],
#               dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# ## `shift`

# %%
# !pip install yfinance -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 KB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 48.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 17.3 MB/s eta 0:00:00

# %%
import yfinance as yf

tqqq = yf.Ticker("TQQQ").history() # 한 달치
tqqq
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-02-14 00:00:00-05:00  24.540001  25.740000  24.049999  25.490000
# 2023-02-15 00:00:00-05:00  25.020000  26.100000  24.850000  26.059999
# 2023-02-16 00:00:00-05:00  24.830000  25.870001  24.530001  24.570000
# 2023-02-17 00:00:00-05:00  24.030001  24.230000  23.299999  24.040001
# 2023-02-21 00:00:00-05:00  23.100000  23.450001  22.290001  22.350000
# 2023-02-22 00:00:00-05:00  22.450001  22.850000  21.980000  22.370001
# 2023-03-09 00:00:00-05:00 -5.263154
# 2023-03-10 00:00:00-05:00 -4.132238
# 2023-03-13 00:00:00-04:00  2.155176

# %%
((df - df.shift(1)) /df.shift(1)).fillna(0).apply(lambda x: f"{x.Close * 100:.2f}%", axis=1)
# Out:
# Date
# 2023-02-14 00:00:00-05:00     0.00%
# 2023-02-15 00:00:00-05:00     2.24%
# 2023-02-16 00:00:00-05:00    -5.72%
# 2023-02-17 00:00:00-05:00    -2.16%
# 2023-02-21 00:00:00-05:00    -7.03%
# 2023-02-22 00:00:00-05:00     0.09%
# 2023-02-23 00:00:00-05:00     2.50%
# 2023-02-24 00:00:00-05:00    -5.06%
# 2023-02-27 00:00:00-05:00     2.16%
# 2023-02-28 00:00:00-05:00    -0.49%
# 2023-03-01 00:00:00-05:00    -2.44%
# 2023-03-02 00:00:00-05:00     2.41%
# 2023-03-03 00:00:00-05:00     6.11%
# 2023-03-06 00:00:00-05:00     0.43%
# 2023-03-07 00:00:00-05:00    -3.74%
# 2023-03-08 00:00:00-05:00     1.37%
# 2023-03-09 00:00:00-05:00    -5.26%
# 2023-03-10 00:00:00-05:00    -4.13%
# 2023-03-13 00:00:00-04:00     2.16%
# dtype: object

# %%
df.index = df.index.date # 날짜만 남고 시간은 떼어짐
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-4286459862a1> in <module>
# ----> 1 df.index = df.index.date # 날짜만 남고 시간은 떼어짐
#
# AttributeError: 'Index' object has no attribute 'date'

# %%
((df - df.shift(1)) /df.shift(1)).fillna(0).apply(lambda x: f"{x.Close * 100:.2f}%", axis=1)
# Out:
# 2023-02-14     0.00%
# 2023-02-15     2.24%
# 2023-02-16    -5.72%
# 2023-02-17    -2.16%
# 2023-02-21    -7.03%
# 2023-02-22     0.09%
# 2023-02-23     2.50%
# 2023-02-24    -5.06%
# 2023-02-27     2.16%
# 2023-02-28    -0.49%
# 2023-03-01    -2.44%
# 2023-03-02     2.41%
# 2023-03-03     6.11%
# 2023-03-06     0.43%
# 2023-03-07    -3.74%
# 2023-03-08     1.37%
# 2023-03-09    -5.26%
# 2023-03-10    -4.13%
# 2023-03-13     2.16%
# dtype: object

# %%
# 시계열의 데이터의 인덱스는 '시간'(순서) => 날짜 이동 => 전날/오늘 데이터 비교, 연산...
# 날짜/시간 -> DatetimeIndex => 인덱스는 그대로 두고 데이터만 이동

# %% [markdown]
# ### `resample` 연산
# * 시간 간격을 재조정
# * 시간 구간을 작게 만든다 -> 데이터 양이 증가 -> 업-샘플링(up-sampling)
# * 시간 구간을 크게 만든다 -> 데이터 양이 감소 -> 다운-샘플링(down-sampling)

# %%
# !pip install pyupbit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 6.9 MB/s eta 0:00:00

# %%
import pyupbit

# %%
pyupbit.get_tickers() # 상장하고 거래되고 있는 종목들
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'BTC-ETH',
#  'BTC-XRP',
#  'BTC-ETC',
#  'BTC-OMG',
#  'BTC-CVC',
#  'BTC-DGB',
#  'BTC-SC',
#  'BTC-SNT',
#  'BTC-WAVES',
#  'BTC-NMR',
#  'BTC-XEM',
#  'BTC-QTUM',
#  'BTC-BAT',
#  'BTC-LSK',
#  'BTC-STEEM',
#  'BTC-DOGE',
#  'BTC-BNT',
#  'BTC-XLM',
#  'BTC-ARDR',
#  'BTC-ARK',
#  'BTC-STORJ',
#  'BTC-GRS',
#  'BTC-REP',
#  'BTC-RLC',
#  'USDT-BTC',
#  'USDT-ETH',
#  'USDT-XRP',
#  'USDT-ETC',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'BTC-ADA',
#  'BTC-MANA',
#  'USDT-OMG',
#  'KRW-SBD',
#  'BTC-SBD',
#  'KRW-POWR',
#  'BTC-POWR',
#  'KRW-BTG',
#  'USDT-ADA',
#  'BTC-DNT',
#  'BTC-ZRX',
#  'BTC-TRX',
#  'BTC-TUSD',
#  'BTC-LRC',
#  'KRW-ICX',
#  'KRW-EOS',
#  'USDT-TUSD',
#  'KRW-TRX',
#  'BTC-POLYX',
#  'USDT-SC',
#  'USDT-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLYX',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'BTC-BCH',
#  'USDT-BCH',
#  'KRW-BCH',
#  'BTC-HIFI',
#  'BTC-LOOM',
#  'KRW-BAT',
#  'KRW-IOST',
#  'BTC-RFR',
#  'KRW-RFR',
#  'USDT-DGB',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'BTC-RVN',
#  'BTC-GO',
#  'BTC-UPP',
#  'BTC-ENJ',
#  'KRW-HIFI',
#  'KRW-ONG',
#  'KRW-GAS',
#  'BTC-MTL',
#  'KRW-UPP',
#  'KRW-ELF',
#  'USDT-DOGE',
#  'USDT-ZRX',
#  'USDT-RVN',
#  'USDT-BAT',
#  'KRW-KNC',
#  'BTC-MOC',
#  'BTC-ZIL',
#  'KRW-BSV',
#  'BTC-BSV',
#  'BTC-IOST',
#  'KRW-THETA',
#  'BTC-DENT',
#  'KRW-QKC',
#  'BTC-ELF',
#  'KRW-BTT',
#  'BTC-IOTX',
#  'BTC-SOLVE',
#  'BTC-NKN',
#  'BTC-META',
#  'KRW-MOC',
#  'BTC-ANKR',
#  'BTC-CRO',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'BTC-ORBS',
#  'BTC-AERGO',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'BTC-ATOM',
#  'BTC-STPT',
#  'KRW-MBL',
#  'BTC-EOS',
#  'BTC-DAI',
#  'BTC-MKR',
#  'BTC-BORA',
#  'KRW-WAXP',
#  'BTC-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'BTC-MED',
#  'BTC-MLK',
#  'KRW-MLK',
#  'KRW-STPT',
#  'BTC-VET',
#  'KRW-ORBS',
#  'BTC-CHZ',
#  'KRW-VET',
#  'BTC-FX',
#  'BTC-OGN',
#  'KRW-CHZ',
#  'BTC-XTZ',
#  'BTC-HIVE',
#  'BTC-HBD',
#  'BTC-OBSR',
#  'BTC-DKA',
#  'KRW-STMX',
#  'BTC-STMX',
#  'BTC-AHT',
#  'BTC-PCI',
#  'KRW-DKA',
#  'BTC-LINK',
#  'KRW-HIVE',
#  'KRW-KAVA',
#  'BTC-KAVA',
#  'KRW-AHT',
#  'KRW-LINK',
#  'KRW-XTZ',
#  'KRW-BORA',
#  'BTC-JST',
#  'BTC-CHR',
#  'BTC-DAD',
#  'BTC-TON',
#  'KRW-JST',
#  'BTC-CTSI',
#  'BTC-DOT',
#  'KRW-CRO',
#  'BTC-COMP',
#  'BTC-SXP',
#  'BTC-HUNT',
#  'KRW-TON',
#  'BTC-ONIT',
#  'BTC-CRV',
#  'BTC-ALGO',
#  'BTC-RSR',
#  'KRW-SXP',
#  'BTC-OXT',
#  'BTC-PLA',
#  'KRW-HUNT',
#  'BTC-MARO',
#  'BTC-SAND',
#  'BTC-SUN',
#  'KRW-PLA',
#  'KRW-DOT',
#  'BTC-SRM',
#  'BTC-QTCON',
#  'BTC-MVL',
#  'KRW-SRM',
#  'KRW-MVL',
#  'BTC-REI',
#  'BTC-AQT',
#  'BTC-AXS',
#  'BTC-STRAX',
#  'KRW-STRAX',
#  'KRW-AQT',
#  'BTC-GLM',
#  'KRW-GLM',
#  'BTC-FCT2',
#  'BTC-SSX',
#  'KRW-SSX',
#  'KRW-META',
#  'KRW-FCT2',
#  'BTC-FIL',
#  'BTC-UNI',
#  'BTC-BASIC',
#  'BTC-INJ',
#  'BTC-PROM',
#  'BTC-VAL',
#  'BTC-PSG',
#  'BTC-JUV',
#  'BTC-CBK',
#  'BTC-FOR',
#  'KRW-CBK',
#  'BTC-BFC',
#  'BTC-LINA',
#  'BTC-HUM',
#  'BTC-CELO',
#  'KRW-SAND',
#  'KRW-HUM',
#  'BTC-IQ',
#  'BTC-STX',
#  'KRW-DOGE',
#  'BTC-NEAR',
#  'BTC-AUCTION',
#  'BTC-DAWN',
#  'BTC-FLOW',
#  'BTC-STRK',
#  'KRW-STRK',
#  'BTC-PUNDIX',
#  'KRW-PUNDIX',
#  'KRW-FLOW',
#  'KRW-DAWN',
#  'KRW-AXS',
#  'KRW-STX',
#  'BTC-GRT',
#  'BTC-SNX',
#  'BTC-USDP',
#  'KRW-XEC',
#  'KRW-SOL',
#  'BTC-SOL',
#  'KRW-MATIC',
#  'BTC-MATIC',
#  'KRW-NU',
#  'BTC-NU',
#  'KRW-AAVE',
#  'KRW-1INCH',
#  'BTC-AAVE',
#  'BTC-1INCH',
#  'BTC-MASK',
#  'KRW-ALGO',
#  'BTC-AUDIO',
#  'KRW-NEAR',
#  'BTC-YGG',
#  'BTC-GTC',
#  'BTC-OCEAN',
#  'BTC-CTC',
#  'BTC-LPT',
#  'KRW-AVAX',
#  'BTC-AVAX',
#  'BTC-IMX',
#  'BTC-RNDR',
#  'BTC-RLY',
#  'KRW-T',
#  'BTC-T',
#  'KRW-CELO',
#  'BTC-RAD',
#  'BTC-AGLD',
#  'BTC-API3',
#  'BTC-ARPA',
#  'BTC-ENS',
#  'KRW-GMT',
#  'BTC-GMT',
#  'BTC-APE',
#  'BTC-RAY',
#  'KRW-APT',
#  'BTC-APT',
#  'BTC-ACM',
#  'BTC-AFC',
#  'BTC-ATM',
#  'BTC-BAR',
#  'BTC-CITY',
#  'BTC-INTER',
#  'BTC-NAP',
#  'KRW-SHIB',
#  'BTC-GAL',
#  'BTC-ASTR',
#  'BTC-BLUR',
#  'KRW-MASK',
#  'BTC-ACS']

# %%
eth =pyupbit.get_ohlcv("KRW-ETH")

# %%
pd.options.display.float_format = "{:2f}".format

# %%
# 다운-샘플링 -> 시간을 더 크게 묶는 거 -> "D(Day)" => "Week?"
eth.resample('W').mean()
# Out:
#                      open           high            low          close  \
# 2022-08-28 2074500.000000 2096000.000000 1992500.000000 2021250.000000
# 2022-09-04 2120857.142857 2196571.428571 2089500.000000 2148857.142857
# 2022-09-11 2269000.000000 2342857.142857 2233428.571429 2303000.000000
# 2022-09-18 2205428.571429 2245285.714286 2088357.142857 2131928.571429
# 2022-09-25 1883428.571429 1943285.714286 1823071.428571 1879285.714286
# 2022-10-02 1904571.428571 1942357.142857 1864285.714286 1904357.142857
# 2022-10-09 1903785.714286 1929357.142857 1881714.285714 1908285.714286
# 2022-10-16 1854285.714286 1885142.857143 1820428.571429 1853571.428571
# 2022-10-23 1876000.000000 1906142.857143 1852714.285714 1887071.428571
# 2022-10-30 2104000.000000 2196571.428571 2073285.714286 2144500.000000
# 2022-11-06 2221428.571429 2281857.142857 2189000.000000 2219428.571429
# 2022-11-13 1898714.285714 1954857.142857 1746428.571429 1823642.857143
# 2022-11-20 1682000.000000 1715571.428571 1633928.571429 1670642.857143
# 2022-11-27 1619714.285714 1647857.142857 1590571.428571 1626428.571429
# 2022-12-04 1686857.142857 1722285.714286 1659071.428571 1696500.000000
# 2022-12-11 1689500.000000 1714071.428571 1665428.571429 1685357.142857
# 2022-12-18 1659428.571429 1682714.285714 1618142.857143 1643857.142857
# 2022-12-25 1576571.428571 1597500.000000 1555071.428571 1578285.714286
# 2023-01-01 1541857.142857 1551071.428571 1519714.285714 1534785.714286
# 2023-01-08 1579071.428571 1604500.000000 1568642.857143 1594857.142857
# 2023-01-15 1743142.857143 1804785.714286 1728642.857143 1784857.142857
# 2023-01-22 1958571.428571 2018642.857143 1931642.857143 1975642.857143
# 2023-01-29 2004357.142857 2041714.285714 1960857.142857 2007500.000000
# 2023-02-05 2045285.714286 2087142.857143 2008642.857143 2047000.000000
# 2023-02-12 2044571.428571 2069357.142857 2003357.142857 2031285.714286
# 2023-02-19 2081571.428571 2146714.285714 2055928.571429 2111642.857143
# 2023-02-26 2156142.857143 2181571.428571 2115571.428571 2158142.857143
# 2023-03-05 2151142.857143 2172000.000000 2113714.285714 2138428.571429
# 2022-10-31 16267.927684  31001648371.883755
# 2022-11-30 26295.823637  58476358599.086937
# 2022-12-31 29415.605675  50990524695.347603
# 2023-01-31  6939.249786  10585761629.683069
# 2023-02-28 32184.490441  64638302315.183380
# 2023-03-31 17948.881441  39110134338.093857

# %%
eth.resample('M').last()
# Out:
#                      open           high            low          close  \
# 2022-08-31 2101000.000000 2209000.000000 2100000.000000 2136000.000000
# 2022-09-30 1910000.000000 1964000.000000 1892500.000000 1911000.000000
# 2022-10-31 2234000.000000 2291000.000000 2184000.000000 2208000.000000
# 2022-11-30 1657000.000000 1766500.000000 1655000.000000 1752500.000000
# 2022-12-31 1524000.000000 1537000.000000 1514000.000000 1525000.000000
# 2023-01-31 1969500.000000 2011000.000000 1952000.000000 1992500.000000
# 2023-02-28 2175000.000000 2188000.000000 2145000.000000 2150000.000000
# 2023-03-31 2200000.000000 2229000.000000 2191000.000000 2209000.000000
#
#                  volume               value
# 2022-08-31 89723.275812 194103998395.423615
# 2022-09-30 43457.254211  83458740837.148407
# 2022-10-31 38155.119935  85097269275.840973
# 2022-11-30 50982.607639  87964238429.107224
# 2022-12-31 10909.811781  16629168260.794081
# 2023-01-31 21724.126658  43002844038.773697
# 2023-02-28 15149.458033  32821483880.050732
# 2023-03-31 11712.244458  25863357108.413471

# %% [markdown]
# ### Down-sampling
# * 1분 -> 10분 묶음 (데이터의 전체 수는 줄이고, 데이터 간의 구간은 늘리는 리샘플링) => 다운-샘플링 => 묶인 데이터들간의 '대표값' => 그룹함수, 집계함수 ==> (대표값)

# %% [markdown]
# ## Up-sampling
# * `ffill` : 앞전 시간대의 값을 불러와줌 (forward)
# * `bfill` : 뒤 시간대의 값을 채워줌 (backward)

# %%
# up-sampling (10분 -> 1분짜리 쪼갬) => 없던거를 만드는 거
# f-fill (front) => 비었을 때 앞전 시간대에 존재하는 데이터로 채워줌
# eth.index = eth.index.date
eth.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-77670a016331> in <module>
#       1 # up-sampling (10분 -> 1분짜리 쪼갬) => 없던거를 만드는 거
#       2 # f-fill (front) => 비었을 때 앞전 시간대에 존재하는 데이터로 채워줌
# ----> 3 eth.index = eth.index.date
#       4 eth.head()
#
# AttributeError: 'Index' object has no attribute 'date'

# %%
eth2 = pyupbit.get_ohlcv("KRW-ETH", interval='minute60')
eth2
# Out:
#                               open           high            low  \
# 2023-03-06 08:00:00 2091000.000000 2098000.000000 2080000.000000
# 2023-03-06 09:00:00 2092000.000000 2096000.000000 2084000.000000
# 2023-03-06 10:00:00 2092000.000000 2097000.000000 2080000.000000
# 2023-03-06 11:00:00 2082000.000000 2088000.000000 2075000.000000
# 2023-03-06 12:00:00 2082000.000000 2085000.000000 2076000.000000
# ...                            ...            ...            ...
# 2023-03-14 11:00:00 2211000.000000 2219000.000000 2202000.000000
# 2023-03-14 12:00:00 2204000.000000 2213000.000000 2201000.000000
# 2023-03-14 13:00:00 2211000.000000 2213000.000000 2202000.000000
# 2023-03-14 14:00:00 2207000.000000 2229000.000000 2200000.000000
# 2023-03-14 15:00:00 2205000.000000 2213000.000000 2204000.000000
#
# 2023-03-06 10:10:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 10:20:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 10:30:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 10:40:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 10:50:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 11:00:00 2082000.000000 777.072205 1616847679.607930
# 2023-03-06 11:10:00 2079000.000000 351.400099  730871360.691680

# %% [markdown]
# ### `dt`

# %%
# dt -> datetime 여러가지 연산, 속성
s = pd.Series(pd.date_range("2023-1-1", periods=100))
s
# Out:
# 0    2023-01-01
# 1    2023-01-02
# 2    2023-01-03
# 3    2023-01-04
# 4    2023-01-05
#         ...
# 95   2023-04-06
# 96   2023-04-07
# 97   2023-04-08
# 98   2023-04-09
# 99   2023-04-10
# Length: 100, dtype: datetime64[ns]

# %%
# dtype -> 일괄적으로 날짜/시간값을 처리할 수 있게 속성값
s.dt

# %%
s.astype('str').str # 열을 str취급함

# %%
s.dt.year
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
#       ...
# 95    2023
# 96    2023
# 97    2023
# 98    2023
# 99    2023
# Length: 100, dtype: int64

# %%
s.dt.month
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 95    4
# 96    4
# 97    4
# 98    4
# 99    4
# Length: 100, dtype: int64

# %%
s.dt.day
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 95     6
# 96     7
# 97     8
# 98     9
# 99    10
# Length: 100, dtype: int64

# %%
s.dt.strftime("%Y-%m-%d")
# Out:
# 0     2023-01-01
# 1     2023-01-02
# 2     2023-01-03
# 3     2023-01-04
# 4     2023-01-05
#          ...
# 95    2023-04-06
# 96    2023-04-07
# 97    2023-04-08
# 98    2023-04-09
# 99    2023-04-10
# Length: 100, dtype: object

# %%
s.dt.weekday
# Out:
# 0     6
# 1     0
# 2     1
# 3     2
# 4     3
#      ..
# 95    3
# 96    4
# 97    5
# 98    6
# 99    0
# Length: 100, dtype: int64

# %% [markdown]
# ---

# %%
# https://financedatareader.readthedocs.io/en/latest/
# !pip install finance-datareader -q
# --quiet

# %%
import FinanceDataReader as fdr # fdr

# %%
fdr.StockListing('KRX') # 현재 상장된 한국 주식데이터 목록
# 삼성전자 : 005930
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          59000          2
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         548000          2
# 2     000660  KR7000660001    SK하이닉스  KOSPI          81100          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         772000          2
# 4     051910  KR7051910008      LG화학  KOSPI         705000          2
# ...      ...           ...       ...    ...    ...     ...        ...
# 2701  267810  KR7267810000        앙츠  KONEX  일반기업부    1093          0
# 2702  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2703  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2704  308700  KR7308700004       테크엔  KONEX  일반기업부     349          2
# 2705  322190  KR7322190000        베른  KONEX  일반기업부      94          2
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# 0       -1000    -1.670000   59400   59500   59000  11972403  708843223400
# 1      -15000    -2.660000  560000  561000  545000    304116  167430665000
# 2       -3200    -3.800000   82600   83000   81100   3327492  271886361900
# 3       -6000    -0.770000  770000  785000  770000     69336   53768269000
# 4      -13000    -1.810000  708000  718000  695000    188447  132488239000
# ...       ...          ...     ...     ...     ...       ...           ...
# 2701        0     0.000000       0       0       0         0             0
# 2702        0     0.000000       0       0       0         0             0
# 2703        0     0.000000       0       0       0         0             0
# 2704      -54   -13.400000     459     459     343      1981        700661
# 2705      -13   -12.150000     113     113      93         6           603
#
#                Marcap      Stocks MarketId
# 0     352814148705000  5969782550      STK
# 1     128466000000000   234000000      STK
# 2      59404992984000   728002365      STK
# 3      54946328000000    71174000      STK
# 4      49838194158000    70592343      STK
# ...               ...         ...      ...
# 2701       1953191000     1787000      KNX
# 2702       1934959392     2121666      KNX
# 2703       1654666524     9141804      KNX
# 2704       1372000000     4000000      KNX
# 2705        937145685     8925197      KNX
#
# [2706 rows x 17 columns]

# %%
df = fdr.StockListing('KRX')

# %%
df[df.Name == 'NAVER']
# Out:
#      Code        ISU_CD   Name Market Dept   Close ChangeCode  Changes  \
# 8  035420  KR7035420009  NAVER  KOSPI       196000          2    -6500
#
#    ChagesRatio    Open    High     Low  Volume        Amount          Marcap  \
# 8    -3.210000  200000  202000  196000  770200  152544193000  32186430477000
#
#       Stocks MarketId
# 8  164049085      STK

# %%
df[df.Name == '카카오']
# Out:
#       Code        ISU_CD Name Market Dept  Close ChangeCode  Changes  \
# 11  035720  KR7035720002  카카오  KOSPI       59400          2    -1400
#
#     ChagesRatio   Open   High    Low   Volume        Amount          Marcap  \
# 11    -2.300000  60600  61100  59200  2181804  130753711600  26467952623200
#
#        Stocks MarketId
# 11  445588428      STK

# %%
se = fdr.DataReader('005930')
se
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-11-26   1340   1358   1306   1312    678740       NaN
# 1998-11-27   1292   1310   1271   1283    613180 -0.022104
# 1998-11-28   1292   1321   1289   1318    264480  0.027280
# 1998-11-30   1335   1335   1268   1276    320470 -0.031866
# 1998-12-01   1254   1254   1162   1197    877940 -0.061912
# ...           ...    ...    ...    ...       ...       ...
# 2023-03-08  60100  60500  59900  60300  14161857 -0.006590
# 2023-03-09  60500  60800  59900  60100  14334499 -0.003317
# 2023-03-10  59500  59700  59100  59500  11902471 -0.009983
# 2023-03-13  59900  60200  59300  60000  12779724  0.008403
# 2023-03-14  59400  59500  59000  59000  11189673 -0.016667
#
# [6000 rows x 6 columns]

# %%
se.resample('MS').first()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-11-01   1340   1358   1306   1312    678740 -0.022104
# 1998-12-01   1254   1254   1162   1197    877940 -0.061912
# 1999-01-01   1776   1776   1624   1693    666160  0.095084
# 1999-02-01   1800   1800   1763   1788    238890  0.016487
# 1999-03-01   1704   1712   1657   1657    419963 -0.017783
# ...           ...    ...    ...    ...       ...       ...
# 2022-11-01  59900  60300  59500  60000  17201647  0.010101
# 2022-12-01  63100  63200  62300  62600  16631445  0.006431
# %%
se.rolling(200).mean()
# nan값은 지워주겠다
se.rolling(200).mean().dropna()
# Out:
#                    Open         High          Low        Close  \
# Date
# 1999-09-15  2327.800000  2402.140000  2271.485000  2337.725000
# 1999-09-16  2344.240000  2418.590000  2286.780000  2353.110000
# 1999-09-17  2359.080000  2434.035000  2301.135000  2368.370000
# 1999-09-20  2374.355000  2449.760000  2316.495000  2384.090000
# 1999-09-21  2391.235000  2467.990000  2333.185000  2402.105000
# ...                 ...          ...          ...          ...
# 2023-03-08 60082.000000 60598.000000 59537.500000 60030.000000
# 2023-03-09 60043.000000 60558.500000 59499.000000 59990.000000
# 2023-03-10 60008.000000 60519.000000 59462.000000 59950.000000
# 2023-03-13 59968.500000 60478.000000 59420.000000 59910.000000
# 2023-03-14 59921.500000 60431.500000 59377.000000 59865.500000
#
#                     Volume    Change
# Date
# 1999-09-15   857196.275000  0.007234
# 1999-09-16   859765.650000  0.007022
# 1999-09-17   864833.525000  0.006898
# 1999-09-20   866518.190000  0.007114
# 1999-09-21   869817.325000  0.007853
# ...                    ...       ...
# 2023-03-08 14527067.080000 -0.000450
# 2023-03-09 14516307.980000 -0.000504
# 2023-03-10 14490451.700000 -0.000510
# 2023-03-13 14493801.965000 -0.000505
# 2023-03-14 14481329.890000 -0.000581
#
# [5800 rows x 6 columns]

# %%
se.rolling(200).mean().Close.dropna().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# !pip install pyupbit -q

# %%
import pyupbit
# https://pyupbit.readthedocs.io/en/latest/
pyupbit.get_ohlcv()
# Out:
#                                open            high             low  \
# 2022-08-27 09:00:00 27954000.000000 28150000.000000 27510000.000000
# 2022-08-28 09:00:00 27739000.000000 27878000.000000 27090000.000000
# 2022-08-29 09:00:00 27098000.000000 28066000.000000 27094000.000000
# 2022-08-30 09:00:00 27792000.000000 28150000.000000 27155000.000000
# 2022-08-31 09:00:00 27314000.000000 27957000.000000 27286000.000000
# ...                             ...             ...             ...
# 2023-03-10 09:00:00 27604000.000000 27605000.000000 26707000.000000
# 2023-03-11 09:00:00 27341000.000000 28023000.000000 26870000.000000
# 2023-03-12 09:00:00 27722000.000000 29300000.000000 27167000.000000
# 2023-03-13 09:00:00 29190000.000000 32000000.000000 28855000.000000
# 2023-03-14 09:00:00 31676000.000000 32630000.000000 31579000.000000
#
#                               close       volume               value
# 2022-08-27 09:00:00 27739000.000000  3125.256463  86963182786.777771
# 2022-08-28 09:00:00 27099000.000000  2480.823587  68413346182.692841
# 2022-08-29 09:00:00 27792000.000000  3709.534914 102229321499.593567
# 2022-08-30 09:00:00 27314000.000000  4229.547371 117154442399.738190
# 2022-08-31 09:00:00 27530000.000000  3677.299074 101805940867.425476
# ...                             ...          ...                 ...
# 2023-03-10 09:00:00 27343000.000000  9730.632240 263312710191.782410
# 2023-03-11 09:00:00 27737000.000000  6228.739374 171121003248.740082
# 2023-03-12 09:00:00 29199000.000000  6122.085574 171678983728.684326
# 2023-03-13 09:00:00 31676000.000000 13888.838210 423405493346.776001
# 2023-03-14 09:00:00 32187000.000000  3608.154159 115741906673.144653
#
# [200 rows x 6 columns]
