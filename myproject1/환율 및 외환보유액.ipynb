# %% [markdown]
# <a href="https://colab.research.google.com/github/KHB2937/DataAnalysis/blob/main/myproject1/%ED%99%98%EC%9C%A8%20%EB%B0%8F%20%EC%99%B8%ED%99%98%EB%B3%B4%EC%9C%A0%EC%95%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 나눔폰트
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 2. 런타임 재시작 -> 런타임 / 런타임 다시 시작 (Ctrl + M .)
exit()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 3. 기본 폰트를 나.바.고로 세팅
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("/content/환율_20230316101511.csv", index_col=0, encoding='cp949')
df = pd.read_csv("/content/외환보유액_20230315184343 (1).csv", index_col=0, encoding='cp949')
df1
# Out:
#                     1993    1994    1995    1996    1997     1998     1999
# 국가(통화단위)별
# 아시아                  NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 대한민국(Won)         802.75  803.46  770.94  805.13  953.58  1394.97  1188.65
# 아프가니스탄(Afghanis)   39.28   38.82   36.57   47.50   47.50    47.50    46.62
# 아르메니아(Drams)        9.11  288.65  405.91  414.04  490.85   504.92   535.06
# 아제르바이잔(Manat)       0.02    0.31    0.88    0.86    0.80     0.77     0.82
# ...                  ...     ...     ...     ...     ...      ...      ...
# 파푸아뉴기니(Kina)        0.98    1.01    1.28    1.32    1.44     2.07     2.57
# 사모아(Tala)           2.57    2.54    2.47    2.46    2.56     2.95     3.01
# 솔로몬제도(SI$)          3.19    3.29    3.41    3.57    3.72     4.82     4.84
# 통가(pa’anga)         1.38    1.32    1.27    1.23    1.26     1.49     1.60
# 바누아투(Vatu)        121.58  116.41  112.11  111.72  115.87   127.52   129.08
#
# [209 rows x 7 columns]

# %%
kmt_df = df.loc[['대한민국', '멕시코', '태국', '미국']]
kmt_df.drop('1993.1', axis='columns', inplace=True)
kmt_df.drop('1994.1', axis='columns', inplace=True)
kmt_df.drop('1995.1', axis='columns', inplace=True)
kmt_df.drop('1997.1', axis='columns', inplace=True)
kmt_df.drop('1998.1', axis='columns', inplace=True)
kmt_df.drop('1999.1', axis='columns', inplace=True)
kmt_df.drop('1996.1', axis='columns', inplace=True)
kmt_df1 = df1.loc[['대한민국(Won)', '멕시코(Pesos)', '태국(Baht)', '미국(US$)']]
kmt_df1
# Out:
#               1993    1994    1995    1996    1997     1998     1999
# 국가(통화단위)별
# 대한민국(Won)   802.75  803.46  770.94  805.13  953.58  1394.97  1188.65
# 멕시코(Pesos)    3.12    3.38    6.42    7.60    7.92     9.14     9.56
# 태국(Baht)     25.32   25.15   24.92   25.34   31.36    41.36    37.81
# 미국(US$)       1.00    1.00    1.00    1.00    1.00     1.00     1.00

# %%
data = {'국가별': ['대한민국', '멕시코', '태국', '미국'],
        '1993': [20262, 25299, 25440, 73406],
        '1994': [25673, 6441, 30279, 74335],
        '1995': [32712, 17045, 36945, 85831],
        '1996': [33237, 19527, 38645, 75089],
        '1997': [20405, 28853, 26892, 69954],
        '1998': [52041, 31863, 29536, 81760],
        '1999': [74055, 31829, 34781, 71548]}

kmt_df = pd.DataFrame(data)
kmt_df = kmt_df.set_index('국가별')

# %%
data1 = {'국가(통화단위)별': ['대한민국(Won)', '멕시코(Pesos)', '태국(Baht)'],
        '1993': [802.75, 3.12, 25.32],
        '1994': [803.46, 3.38, 25.15],
        '1995': [770.94, 6.42, 24.92],
        '1996': [805.13, 7.60, 25.34],
        '1997': [953.58, 7.92, 31.36],
        '1998': [1394.97, 9.14, 41.36],
        '1999': [1188.65, 9.56, 37.81]
        }

kmt_df1 = pd.DataFrame(data1)
kmt_df1 = kmt_df1.set_index('국가(통화단위)별')
kmt_df1
# Out:
#               1993    1994    1995    1996    1997     1998     1999
# 국가(통화단위)별
# 대한민국(Won)   802.75  803.46  770.94  805.13  953.58  1394.97  1188.65
# 멕시코(Pesos)    3.12    3.38    6.42    7.60    7.92     9.14     9.56
# 태국(Baht)     25.32   25.15   24.92   25.34   31.36    41.36    37.81

# %%
korea2 = kmt_df1.loc['대한민국(Won)']

# 막대 그래프로 표현
plt.plot(korea2.index, korea2.values)

# 그래프 제목과 축 이름 설정
plt.title('대한민국 환율')
plt.xlabel('연도')
plt.ylabel('환율')

# 그래프 출력
plt.show()

# %%
korea = kmt_df.loc['대한민국']

# 막대 그래프로 표현
plt.plot(korea.index, korea.values)

# 그래프 제목과 축 이름 설정
plt.title('대한민국 환율,외환보유액')
plt.xlabel('연도')
plt.ylabel('달 러')

# 그래프 출력
plt.show()

# %%
import matplotlib.pyplot as plt

# 국가별 데이터 선택
korea1 = kmt_df.loc['대한민국']
korea2 = kmt_df1.loc['대한민국(Won)']

# subplots로 두 개의 그래프 영역을 만듦
fig, ax = plt.subplots(2, 1, figsize=(8, 6), sharex=True)

# 첫 번째 subplot에 그래프 그리기
ax[0].plot(korea1.index, korea1.values, color='blue')
ax[0].set_title('대한민국 외환 보유액')
ax[0].set_ylabel('달러')

# 두 번째 subplot에 그래프 그리기
ax[1].plot(korea2.index, korea2.values, color='red')
ax[1].set_title('대한민국 환율')
ax[1].set_ylabel('원(won)')

# 전체 그래프 제목과 축 이름 설정
plt.suptitle('대한민국 환율 및 외환보유액')
plt.xlabel('연도')
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.95, wspace=0.4, hspace=0.4)
# 그래프 출력
plt.show()
